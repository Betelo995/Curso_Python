# %% [markdown]
# # Listas II
# ## Taller Python TCU- Tropicalización de la Tecnología
# ### Isaac Rojas Hernández
# ### B76693

# %% [markdown]
# Para este cuaderno de jupyter vamos a ver un uso real de las listas como estructura de datos, utilizaremos el ejemplo de la clínica nutricional y el calculo de IMC, sin embargo ahora para que se puedan registrar $n$ cantidad de personas y dejar el registro como tal almacenado en una lista. Utilizaremos también otros conocimientos previos como lo son el manejo de errores.
#
# Lo primero que debemos hacer es pedirle al usuario cuántas personas desea calcular en este uso del programa, para ello usaremos también manejo de errores así si ocurre algún dato mal insertado el usuario se percate a tiempo.
# ```Python
# import math as mt
# try:
#     n = int(input("Ingrese la cantidad de personas: "))
#     persona = 1
#     i = 0
# except:
#     print("Esa no es una cantidad valida de personas!")
#
# ```
# Una vez solicitada la cantidad de personas debemos crear 3 listas, una para los nombres, otra para almacenar el IMC y otro para poder guardar la calificación que se le da a la persona dependiendo de cada IMC, hay otra forma de solucionar este problema utilizando una clase que almacene estos datos como atributos y solamente se almacenen los objetos dentro de una lista, pero vamos a hacerlo de la forma clásica para demostrar aún más el uso de las listas.
# ```Python
# import math as mt
# try:
#     n = int(input("Ingrese la cantidad de personas: "))
#     persona = 1
#     i = 0
# except:
#     print("Esa no es una cantidad valida de personas!")
#
#
# try:
#     lista_personas = []
#     lista_IMC = []
#     lista_clasif = []
#
# except:
#
# ```
#
# Ahora solamente debemos utilizar el mismo código del programa pasado, para calcular el IMC y determinar cual es la categoría de las personas.
# ```Python
# import math as mt
# try:
#     n = int(input("Ingrese la cantidad de personas: "))
#     persona = 1
#     i = 0
# except:
#     print("Esa no es una cantidad valida de personas!")
#
#
# try:
#     lista_personas = []
#     lista_IMC = []
#     lista_clasif = []
#
#     while persona <= n:
#         nombre = input("Ingrese el nombre de la persona: ")
#         edad = int(input("Ingrese la edad de la persona: "))
#         altura = float(input("Ingrese la estatura de la persona: "))
#         metros = altura/100
#         masa = float(input("Ingrese la masa en kg de la persona: "))
#         lista_personas.append(nombre)
#
#         if edad >= 18:
#             IMC = (masa)/(mt.pow(metros, 2))
#             lista_IMC.append(IMC)
#             if IMC <= 15.99:
#                 clasi = str("Delgadez severa")
#                 lista_clasif.append(clasi)
#
#             elif 16.00 <= IMC and IMC <= 16.99:
#                 clasi = str("Delgadez moderada")
#                 lista_clasif.append(clasi)
#
#             elif 17.00 <= IMC and IMC <= 18.49:
#                 clasi = str("Delgadez leve")
#                 lista_clasif.append(clasi)
#
#             elif 18.50 <= IMC and IMC <= 24.99:
#                 clasi = str("Normal")
#                 lista_clasif.append(clasi)
#
#             elif 25.00 <= IMC and IMC <= 29.99:
#                 clasi = str("Sobrepeso")
#                 lista_clasif.append(clasi)
#
#             elif 30.00 <= IMC and IMC <= 34.99:
#                 clasi = str("Obesidad leve")
#                 lista_clasif.append(clasi)
#
#             elif 35.00 <= IMC and IMC <= 39.00:
#                 clasi = str("Obesidad media")
#                 lista_clasif.append(clasi)
#
#             elif IMC >= 40.00:
#                 clasi = str("Obesidad morbida")
#                 lista_clasif.append(clasi)
#
#         elif edad < 18:
#             err = str("Este programa sólo puede clasificar los IMC para personas mayores de 18 años!!")
#             IMC = 0
#             lista_IMC.append(IMC)
#             lista_clasif.append(err)
#
#         persona = persona + 1
#
#     for i in range(0, n, 1):
#         print(lista_personas[i], " tiene un IMC de: ", lista_IMC[i], " y entra en la categoría de: ", lista_clasif[i])
#
# except:
#     print("El dato ingresado no es válido, intentelo de nuevo. ")
#
#
# ```

# %% [markdown]
# Además vamos a agregar a este ejemplo la impresión de las tres listas para que puedan ver que en las 3 los datos calzan correspondientemente a cual sea su posición dentro de la lista, dando como resultado el siguiente programa:

# %%
import math as mt
try:
    n = int(input("Ingrese la cantidad de personas: "))
    persona = 1
    i = 0
except: 
    print("Esa no es una cantidad valida de personas!")
    
    
try:
    lista_personas = []
    lista_IMC = []
    lista_clasif = []

    while persona <= n:
        nombre = input("Ingrese el nombre de la persona: ")
        edad = int(input("Ingrese la edad de la persona: "))
        altura = float(input("Ingrese la estatura de la persona: "))
        metros = altura/100
        masa = float(input("Ingrese la masa en kg de la persona: "))
        lista_personas.append(nombre)

        if edad >= 18:
            IMC = (masa)/(mt.pow(metros, 2))
            lista_IMC.append(IMC)
            if IMC <= 15.99:
                clasi = str("Delgadez severa")
                lista_clasif.append(clasi)

            elif 16.00 <= IMC and IMC <= 16.99:
                clasi = str("Delgadez moderada")
                lista_clasif.append(clasi)

            elif 17.00 <= IMC and IMC <= 18.49:
                clasi = str("Delgadez leve")
                lista_clasif.append(clasi)

            elif 18.50 <= IMC and IMC <= 24.99:
                clasi = str("Normal")
                lista_clasif.append(clasi)

            elif 25.00 <= IMC and IMC <= 29.99:
                clasi = str("Sobrepeso")
                lista_clasif.append(clasi)

            elif 30.00 <= IMC and IMC <= 34.99:
                clasi = str("Obesidad leve")
                lista_clasif.append(clasi)

            elif 35.00 <= IMC and IMC <= 39.00:
                clasi = str("Obesidad media")
                lista_clasif.append(clasi)

            elif IMC >= 40.00:
                clasi = str("Obesidad morbida")
                lista_clasif.append(clasi)

        elif edad < 18:
            err = str("Este programa sólo puede clasificar los IMC para personas mayores de 18 años!!")
            IMC = 0
            lista_IMC.append(IMC)
            lista_clasif.append(err)

        persona = persona + 1

    for i in range(0, n, 1):
        print(lista_personas[i], " tiene un IMC de: ", lista_IMC[i], " y entra en la categoría de: ", lista_clasif[i])

except:
    print("El dato ingresado no es válido, intentelo de nuevo. ")

print(lista_IMC)
print(lista_IMC)
print(lista_clasif)
